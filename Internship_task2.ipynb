# %% [markdown]
# 1 . Given a valid (IPv4) IP address, return a defanged version of that IP address.
#
# A defanged IP address replaces every period "." with "[.]".
#
#
#
# Example 1:
#
# Input: address = "1.1.1.1"
# Output: "1[.]1[.]1[.]1"
# Example 2:
#
# Input: address = "255.100.50.0"
# Output: "255[.]100[.]50[.]0"

# %%
IP = input("enter a ip address")

def defang(IP):
  result = ""
  for i in IP:
    if i != ".":
      result += i
    else:
      result += "[.]"
  return result

defang(IP)
# Out:
# enter a ip address1.1.1.1
# '1[.]1[.]1[.]1'

# %% [markdown]
# 2. Given an array nums of integers, return how many of them contain an even number of digits.
#
#
#
# Example 1:
#
# Input: nums = [12,345,2,6,7896]
# Output: 2
# Explanation:
# 12 contains 2 digits (even number of digits).
# 345 contains 3 digits (odd number of digits).
# 2 contains 1 digit (odd number of digits).
# 6 contains 1 digit (odd number of digits).
# 7896 contains 4 digits (even number of digits).
# Therefore only 12 and 7896 contain an even number of digits.

# %%
list1 = list(map(int,input("enter numbers").split()))

def count_even_digit_numbers(list1):
  count_even = 0
  for i in list1:
    count = 0
    while(i>0):
      count += 1
      i = i/10
    if count%2 == 0:
      count_even += 1
  return count_even

count_even_digit_numbers(list1)
# Out:
# enter numbers12 345 2 6 7896
# 2

# %% [markdown]
# 3. Given an array of integers nums, return the number of good pairs.
#
# A pair (i, j) is called good if nums[i] == nums[j] and i < j.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,1,1,3]
# Output: 4
# Explanation: There are 4 good pairs (0,3), (0,4), (3,4), (2,5) 0-indexed.

# %%
arr = list(map(int,input("enter numbers:").split()))

def count_good_pair(arr):
    count = 0
    for i in range(len(arr)):
        for j in range(i + 1, len(arr)):
            if arr[i] == arr[j]:
                count += 1
    return count

count_good_pair(arr)
# Out:
# enter numbers:1 2 3 1 1 3
# 4

# %% [markdown]
# 4 . Given the array nums, for each nums[i] find out how many numbers in the array are smaller than it. That is, for each nums[i] you have to count the number of valid j's such that j != i and nums[j] < nums[i].
#
# Return the answer in an array.
#
#
#
# Example 1:
#
# Input: nums = [8,1,2,2,3]
# Output: [4,0,1,1,3]
# Explanation:
# For nums[0]=8 there exist four smaller numbers than it (1, 2, 2 and 3).
# For nums[1]=1 does not exist any smaller number than it.
# For nums[2]=2 there exist one smaller number than it (1).
# For nums[3]=2 there exist one smaller number than it (1).
# For nums[4]=3 there exist three smaller numbers than it (1, 2 and 2).

# %%
arr = list(map(int,input("enter numbers:").split()))

def smaller_than_current(arr):
  new_arr = []
  for i in range(len(arr)):
      count = 0
      for j in range(len(arr)):
        if arr[j] < arr[i]:
          count += 1
      new_arr = new_arr + [count]
  return new_arr

smaller_than_current(arr)
# Out:
# enter numbers:8 1 2 2 3
# [4, 0, 1, 1, 3]

# %% [markdown]
# 5. Given an integer number n, return the difference between the product of its digits and the sum of its digits.
#
#
# Example 1:
#
# Input: n = 234
# Output: 15
# Explanation:
# Product of digits = 2 * 3 * 4 = 24
# Sum of digits = 2 + 3 + 4 = 9
# Result = 24 - 9 = 15

# %%
num = int(input("enter a number:"))

def sub_prod_sum(num):
  prod = 1
  sum = 0
  while(num>0):
    digit = num%10
    prod = prod * digit
    sum = sum + digit
    num = num//10
  return prod - sum

sub_prod_sum(num)
# Out:
# enter a number:234
# 15

# %% [markdown]
# 6.You are given an integer n and an integer start.
#
# Define an array nums where nums[i] = start + 2 * i (0-indexed) and n == nums.length.
#
# Return the bitwise XOR of all elements of nums.
#
#
#
# Example 1:
#
# Input: n = 5, start = 0
# Output: 8
# Explanation: Array nums is equal to [0, 2, 4, 6, 8] where (0 ^ 2 ^ 4 ^ 6 ^ 8) = 8.
# Where "^" corresponds to bitwise XOR operator.

# %%
n = int(input("enter a number:"))
start = int(input("enter the starting number:"))

def create_array(n,start):
  arr = []
  for i in range(n):
    arr = arr + [start + 2*i]
  return arr

def xor(n,start):
  arr = create_array(n,start)
  xor = 0
  for i in arr:
    xor = xor ^ i
  return xor

xor(n,start)
# Out:
# enter a number:5
# enter the starting number:0
# 8
